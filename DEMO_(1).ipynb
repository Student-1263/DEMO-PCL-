# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 62.2 MB/s eta 0:00:00
# ...

# %%
# !pwd
# !ls
# Out:
# /content
#  best.pt   sample_data	'test(1).jpg'   test.jpg

# %%
from ultralytics import YOLO

model = YOLO("best.pt")

results = model("test(1).jpg", save=True, conf=0.25)
# Out:
# image 1/1 /content/test(1).jpg: 384x640 4 No_Helmets, 1040.3ms
# Speed: 13.3ms preprocess, 1040.3ms inference, 35.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict-2

# %%
from IPython.display import Image
Image("runs/detect/predict-2/test(1).jpg")

# %%
from ultralytics import YOLO

model = YOLO("best.pt")

results = model("test(2).jpg", save=True, conf=0.25)
# Out:
# image 1/1 /content/test(2).jpg: 512x640 1 Helmet, 1681.2ms
# Speed: 4.4ms preprocess, 1681.2ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to /content/runs/detect/predict-6

# %%
from IPython.display import Image
Image("runs/detect/predict-6/test(2).jpg")
